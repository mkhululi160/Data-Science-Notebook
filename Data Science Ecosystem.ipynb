# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia
# 6. Scala

# %% [markdown]
# **Objectives:**
# * Python
# * R
# * SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# Pandas: Used for data manipulation and analysis.
#
# Numpy: Provides support for efficient numerical computations and multi-dimensional arrays.
#
# Scikit-learn: Offers simple and efficient tools for machine learning and predictive data analysis.
#
# Matplotlib: A plotting library for creating static, interactive, and animated data visualizations.
#
# TensorFlow: An open-source platform for machine learning and deep learning.
#
# PyTorch: An open-source machine learning framework used for deep learning research and deployment.
#
# Seaborn: A high-level interface for drawing attractive statistical graphics built on matplotlib.
#
# SciPy: An ecosystem of mathematical functions and algorithms for scientific and technical computing.

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebooks  |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
result = (3 * 4) + 5
print(result)
# Out:
# 17

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Mkhululi Van Heerden
